# %%
import pandas as pd

# %% [markdown]
# ## reading csv file

# %%
pd.read_csv(r"/Users/rajbunny/Downloads/phones_.csv")
# Out:
#      Unnamed: 0    Brand      Color  Storage  Rating  Screen_size  Battery  \
# 0             0   realme       Gold       64     4.6          6.7     5000
# 1             1   realme      Black       64     4.3          6.7     5000
# 2             2     vivo       Blue      128     4.4          6.6     5000
# 3             3     vivo      Black      128     4.4          6.6     5000
# 4             4     vivo       Blue      128     4.3          6.6     5000
# ..          ...      ...        ...      ...     ...          ...      ...
# 923         955  SAMSUNG     Silver      128     4.3          6.5     6000
# 924         956     OPPO     Orange       64     4.3          6.6     5000
# 925         957  OnePlus      Green      256     4.1          6.7     5000
# 926         958    APPLE  Starlight      512     4.7          6.1     5000
# 927         959   realme     Orange      256     4.3          6.7     5000
#
#      Price Rating_cat   Price_cat
# ...

# %% [markdown]
# ## pharse error

# %%
pd.read_csv(r"/Users/rajbunny/Downloads/text (1).csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pd.read_csv(r"/Users/rajbunny/Downloads/text (1).csv")
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
# ...

# %% [markdown]
# ## to avoid the pharse error we can on_bad_lines we can skip,warn

# %%
pd.read_csv(r"/Users/rajbunny/Downloads/text (1).csv",on_bad_lines="skip")
# Out:
#       Name  Age Gender
# 0  Bhargav   29      m
# 1   suresh   31      m
# 2   naresh   52      m
# 3   swetha   41      f

# %%
pd.read_csv(r"/Users/rajbunny/Downloads/text (1).csv",on_bad_lines="warn")
# Out:
# Skipping line 6: expected 3 fields, saw 4
#       Name  Age Gender
# 0  Bhargav   29      m
# 1   suresh   31      m
# 2   naresh   52      m
# 3   swetha   41      f

# %% [markdown]
# ## to avoid encoding issue

# %%
import encodings
var=encodings.aliases.aliases.keys()
for y in var:
    try:
        pd.read_csv(r"/Users/rajbunny/Downloads/spam.csv",encoding=y,on_bad_lines="skip")
        print(y)
    except:
        pass
# Out:
# 037
# csibm037
# ebcdic_cp_ca
# ebcdic_cp_nl
# ebcdic_cp_us
# ebcdic_cp_wt
# ibm037
# ibm039
# 1026
# csibm1026
# ibm1026
# 1125
# ibm1125
# cp866u
# ruscii
# 1140
# ibm1140
# 1250
# windows_1250
# 1251
# windows_1251
# 1252
# windows_1252
# 1256
# windows_1256
# 1257
# windows_1257
# 273
# ibm273
# csibm273
# 437
# cspc8codepage437
# ibm437
# 500
# csibm500
# ebcdic_cp_be
# ebcdic_cp_ch
# ibm500
# 775
# cspc775baltic
# ibm775
# 850
# cspc850multilingual
# ibm850
# 852
# cspcp852
# ibm852
# 855
# csibm855
# ibm855
# 858
# csibm858
# ibm858
# 860
# csibm860
# ibm860
# 861
# cp_is
# csibm861
# ibm861
# 862
# cspc862latinhebrew
# ibm862
# 863
# csibm863
# ibm863
# 864
# csibm864
# ibm864
# 865
# csibm865
# ibm865
# 866
# csibm866
# ibm866
# 869
# cp_gr
# csibm869
# ibm869
# roman8
# r8
# cp1051
# ibm1051
# csisolatin6
# iso_8859_10
# iso_8859_10_1992
# iso_ir_157
# l6
# latin6
# iso_8859_13
# l7
# latin7
# iso_8859_14
# iso_8859_14_1998
# iso_celtic
# iso_ir_199
# l8
# latin8
# ...

# %%
pd.read_csv(r"/Users/rajbunny/Downloads/spam.csv",encoding="latin6",on_bad_lines="skip")
# Out:
#         v1                                                 v2 Unnamed: 2  \
# 0      ham  Go until jurong point, crazy.. Available only ...        NaN
# 1      ham                      Ok lar... Joking wif u oni...        NaN
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3      ham  U dun say so early hor... U c already then say...        NaN
# 4      ham  Nah I don't think he goes to usf, he lives aro...        NaN
# ...    ...                                                ...        ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...        NaN
# 5568   ham              Will Ė_ b going to esplanade fr home?        NaN
# 5569   ham  Pity, * was in mood for that. So...any other s...        NaN
# 5570   ham  The guy did some bitching but I acted like i'd...        NaN
# 5571   ham                         Rofl. Its true to its name        NaN
#
#      Unnamed: 3 Unnamed: 4
# 0           NaN        NaN
# 1           NaN        NaN
# ...

# %% [markdown]
# ## memory issue use chunk size
