# %%
import pandas as pd

# %% [markdown]
# ## How to read a exel file

# %%
pd.read_excel(r"/Users/rajbunny/Downloads/FSI-2023-DOWNLOAD.xlsx")
# Out:
#                        Country  Year   Rank  Total  S1: Demographic Pressures  \
# 0                      Somalia  2023    1st  111.9                       10.0
# 1                        Yemen  2023    2nd  108.9                        9.6
# 2                  South Sudan  2023    3rd  108.5                        9.7
# 3    Congo Democratic Republic  2023    4th  107.2                        9.7
# 4                        Syria  2023    5th  107.1                        7.4
# ..                         ...   ...    ...    ...                        ...
# 174                Switzerland  2023  175th   17.8                        2.4
# 175                New Zealand  2023  176th   16.7                        1.1
# 176                    Finland  2023  177th   16.0                        1.7
# 177                    Iceland  2023  178th   15.7                        1.5
# 178                     Norway  2023  179th   14.5                        1.4
#
# ...

# %% [markdown]
# ## how to read exel file having multiple sheets

# %%
df=pd.read_excel(r"/Users/rajbunny/Downloads/Book3.xlsx",sheet_name=[0,1,2])

# %%
df.keys()
# Out:
# dict_keys([0, 1, 2])

# %% [markdown]
# ## keys will be the sheet name what we have given and values will be the data_frame....

# %%
df[0]
# Out:
#   Name  Age
# 0   p1   25
# 1   p2   26
# 2   p3   24
# 3   p4   23
# 4   p5   53

# %%
df[1]
# Out:
#    math  hindi
# 0    25     89
# 1    63     56
# 2    85     28
# 3    45     75
# 4    65     63

# %%
df[2]
# Out:
#    math  hindi
# 0    25     89
# 1    56     56
# 2    85     28
# 3    45     56
# 4    65     63

# %% [markdown]
# ## saving back to exel form the data frame...

# %%
with pd.ExcelWriter(r'/Users/rajbunny/Downloads/untitled folder.xlsx',mode="x") as f2:
    df[0].to_excel(f2,sheet_name='student_info')
    df[1].to_excel(f2,sheet_name='sem1')
    df[2].to_excel(f2,sheet_name='sem2')
