# %% [markdown]
# ## how to read xml file

# %%
import pandas as pd

# %%
pd.read_xml(r"/Users/rajbunny/Downloads/sample1 (1).xml")
# Out:
#          name   age                   email                 title  \
# 0    John Doe  30.0    john.doe@example.com                  None
# 1  Jane Smith  25.0  jane.smith@example.com                  None
# 2        None   NaN                    None  The Adventure Begins
# 3        None   NaN                    None          Harry Potter
#
#            author    year
# 0            None     NaN
# 1            None     NaN
# 2  Robert Johnson  2022.0
# 3             Leo  2023.0

# %% [markdown]
# ## XPath helps pick specific parts of an XML file

# %%
data=pd.read_xml(r"/Users/rajbunny/Downloads/sample3.xml",xpath="person")
data
# Out:
#           name  age                   email
# 0     John Doe   30    john.doe@example.com
# 1   Jane Smith   25  jane.smith@example.com
# 2     John Doe   30    john.doe@example.com
# 3   Jane Smith   25  jane.smith@example.com
# 4     John Doe   30    john.doe@example.com
# 5   Jane Smith   25  jane.smith@example.com
# 6     John Doe   30    john.doe@example.com
# 7   Jane Smith   25  jane.smith@example.com
# 8     John Doe   30    john.doe@example.com
# 9   Jane Smith   25  jane.smith@example.com
# 10    John Doe   30    john.doe@example.com
# 11  Jane Smith   25  jane.smith@example.com
# 12    John Doe   30    john.doe@example.com
# 13  Jane Smith   25  jane.smith@example.com
# 14    John Doe   30    john.doe@example.com
# 15  Jane Smith   25  jane.smith@example.com
# 16    John Doe   30    john.doe@example.com
# 17  Jane Smith   25  jane.smith@example.com
# 18    John Doe   30    john.doe@example.com
# 19  Jane Smith   25  jane.smith@example.com
# ...

# %%
pd.read_xml(r"/Users/rajbunny/Downloads/sample3.xml",xpath="book")
# Out:
#                    title          author  year
# 0   The Adventure Begins  Robert Johnson  2022
# 1   The Adventure Begins  Robert Johnson  2022
# 2   The Adventure Begins  Robert Johnson  2022
# 3   The Adventure Begins  Robert Johnson  2022
# 4   The Adventure Begins  Robert Johnson  2022
# 5   The Adventure Begins  Robert Johnson  2022
# 6   The Adventure Begins  Robert Johnson  2022
# 7   The Adventure Begins  Robert Johnson  2022
# 8   The Adventure Begins  Robert Johnson  2022
# 9   The Adventure Begins  Robert Johnson  2022
# 10  The Adventure Begins  Robert Johnson  2022
# 11  The Adventure Begins  Robert Johnson  2022
# 12  The Adventure Begins  Robert Johnson  2022
# 13  The Adventure Begins  Robert Johnson  2022
# 14  The Adventure Begins  Robert Johnson  2022
# 15  The Adventure Begins  Robert Johnson  2022
# 16  The Adventure Begins  Robert Johnson  2022
# 17  The Adventure Begins  Robert Johnson  2022
# 18  The Adventure Begins  Robert Johnson  2022
# ...

# %% [markdown]
# ## save back to xml

# %%
data.to_xml()
# Out:
# "<?xml version='1.0' encoding='utf-8'?>\n<data>\n  <row>\n    <index>0</index>\n    <name>John Doe</name>\n    <age>30</age>\n    <email>john.doe@example.com</email>\n  </row>\n  <row>\n    <index>1</index>\n    <name>Jane Smith</name>\n    <age>25</age>\n    <email>jane.smith@example.com</email>\n  </row>\n  <row>\n    <index>2</index>\n    <name>John Doe</name>\n    <age>30</age>\n    <email>john.doe@example.com</email>\n  </row>\n  <row>\n    <index>3</index>\n    <name>Jane Smith</name>\n    <age>25</age>\n    <email>jane.smith@example.com</email>\n  </row>\n  <row>\n    <index>4</index>\n    <name>John Doe</name>\n    <age>30</age>\n    <email>john.doe@example.com</email>\n  </row>\n  <row>\n    <index>5</index>\n    <name>Jane Smith</name>\n    <age>25</age>\n    <email>jane.smith@example.com</email>\n  </row>\n  <row>\n    <index>6</index>\n    <name>John Doe</name>\n    <age>30</age>\n    <email>john.doe@example.com</email>\n  </row>\n  <row>\n    <index>7</index>\n    <name>
# ...
